# %% [markdown]
# ## What is Data Wrangling?
# Data wrangling is the process of converting raw data into a usable form

# %% [markdown]
# ## Exploratory data analysis (EDA)
# EDA is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods.

# %% [markdown]
# **Essential Steps in EDA:**
#
# - Data Cleaning
# - Data Summary and visualization
#     - Descriptive Statistics: Calculate basic statistics like mean, median, mode, standard deviation, and variance to summarize and describe the data.
#     - Data visualization: Create visual representations of the data, such as bar charts, histograms, scatter plots, and box plots, to help identify patterns and relationships.
#         - Distributions
#         - Outliers
#     - Handling Missing Data
#     - Data formatting
#     - Transformation
# - Encoding and featurization (feature engineering)
#
# **Exploratory data analysis tools**:
#
# - **Clustering and dimension reduction** techniques, which help create graphical displays of high-dimensional data containing many variables.
# - **Univariate visualization** of each field in the raw dataset, with summary statistics.
# - **Bivariate visualizations** and summary statistics that allow you to assess the relationship between each variable in the dataset and the target variable you’re looking at.
# - **Multivariate visualizations**, for mapping and understanding interactions between different fields in the data.

# %% [markdown]
# **Do you remember our webinar on Data Storytelling ??**
# - Exploratory Analysis
# - Explanatory Analysis

# %% [markdown]
# **We do more of Exploratory Analysis Here**
# - There is no special way to go about it
# - You just have to be investigative and skillfull in your search

# %% [markdown]
# ### We will learn several ways and function we can use. STAY TUNED!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# **We will be working with accident Data captured in UK**

# %%
# import Datasets
df_acc= pd.read_csv("accident_cases.csv")
# Out:
# C:\Users\Abayomi\AppData\Local\Temp\ipykernel_10520\472797817.py:2: DtypeWarning: Columns (1,3,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_acc= pd.read_csv("accident_cases.csv")

# %%
df_acc
# Out:
#         Unnamed: 0   accident_index  accident_year accident_reference  \
# 0                0  2017010000000.0           2017           10001708
# 1                1  2017010000000.0           2017           10009342
# 2                2  2017010000000.0           2017           10009344
# 3                3  2017010000000.0           2017           10009348
# 4                4  2017010000000.0           2017           10009350
# ...            ...              ...            ...                ...
# 461347      461347  2020990000000.0           2020          991027064
# 461348      461348  2020990000000.0           2020          991029573
# 461349      461349  2020990000000.0           2020          991030297
# 461350      461350  2020990000000.0           2020          991030900
# 461351      461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# ...

# %%
df_cas  = pd.read_csv("casualty.csv")
# Out:
# C:\Users\Abayomi\AppData\Local\Temp\ipykernel_10520\1480376460.py:1: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cas  = pd.read_csv("casualty.csv")

# %%
df_cas
# Out:
#         Unnamed: 0  casualty_index accident_index  accident_year  \
# 0                0               0  2017010001708           2017
# 1                1               1  2017010001708           2017
# 2                2               2  2017010001708           2017
# 3                3               3  2017010009342           2017
# 4                4               4  2017010009344           2017
# ...            ...             ...            ...            ...
# 600327      600327          600327  2020991027064           2020
# 600328      600328          600328  2020991029573           2020
# 600329      600329          600329  2020991030297           2020
# 600330      600330          600330  2020991030900           2020
# 600331      600331          600331  2020991032575           2020
#
#        accident_reference  vehicle_reference  casualty_reference  \
# 0               010001708                  1                   1
# ...

# %% [markdown]
# **You need to understand the Domain of the task you are given before you start doing anything**
# - Let's go and read the provided manual to understand the dataset. Some information looks confusing. Right?

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **What do you observe to be aberrant in the imported datasets?**

# %% [markdown]
# **Repeated Column right - 'Unnamed:0'**
# - It is common. You have to deal with it

# %% [markdown]
# **Lesson 1**: How to drop unwanted columns and entries

# %%
#data.drop(['column1', 'column2'])
df_acc.drop(['Unnamed: 0'], axis=1)

## Important argument you must take note of "axis"
## axis = 0 (for rows, you will use the index name)
## axis = 1 (for columns, you will use the column name)
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
df_acc
# Out:
#         Unnamed: 0   accident_index  accident_year accident_reference  \
# 0                0  2017010000000.0           2017           10001708
# 1                1  2017010000000.0           2017           10009342
# 2                2  2017010000000.0           2017           10009344
# 3                3  2017010000000.0           2017           10009348
# 4                4  2017010000000.0           2017           10009350
# ...            ...              ...            ...                ...
# 461347      461347  2020990000000.0           2020          991027064
# 461348      461348  2020990000000.0           2020          991029573
# 461349      461349  2020990000000.0           2020          991030297
# 461350      461350  2020990000000.0           2020          991030900
# 461351      461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# ...

# %% [markdown]
# #### I thought we just dropped the Unnamed:0 guy, what happened!

# %%
## The above does not remain permanant if you do not set the inplace to be True
## Quite common with several functions

df_acc.drop(['Unnamed: 0'], axis=1, inplace=True)

df_cas.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df_cas
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 0                    0  2017010001708           2017          010001708
# 1                    1  2017010001708           2017          010001708
# 2                    2  2017010001708           2017          010001708
# 3                    3  2017010009342           2017          010009342
# 4                    4  2017010009344           2017          010009344
# ...                ...            ...            ...                ...
# 600327          600327  2020991027064           2020          991027064
# 600328          600328  2020991029573           2020          991029573
# 600329          600329  2020991030297           2020          991030297
# 600330          600330  2020991030900           2020          991030900
# 600331          600331  2020991032575           2020          991032575
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %% [markdown]
# ### What Next?
# You can decide to read the guidline to remove more abberants or some other ways

# %% [markdown]
# **You can decide to carry out descriptive statistical analysis**

# %%
# Summary statistics on Numerical Values
df_acc.describe()

## You can from here identify outliers and missing values
# Out:
#        accident_year  location_easting_osgr  location_northing_osgr  \
# count  461352.000000          461236.000000            4.612360e+05
# mean     2018.368378          452593.115756            2.801803e+05
# std         1.091566           94822.718705            1.515501e+05
# min      2017.000000           64084.000000            1.023500e+04
# 25%      2017.000000          388539.000000            1.755300e+05
# 50%      2018.000000          459198.500000            2.208650e+05
# 75%      2019.000000          529290.000000            3.865510e+05
# max      2020.000000          655391.000000            1.209512e+06
#
#            longitude       latitude   police_force  accident_severity  \
# count  461226.000000  461226.000000  461352.000000      461352.000000
# mean       -1.246998      52.408849      28.193388           2.784436
# std         1.389702       1.365101      24.801609           0.443648
# min        -7.525273      49.912362       1.000000           1.000000
# ...

# %%
## Do you remember the loc we talked about last week
df_desc = df_acc.describe()
df_desc.loc['count']
# Out:
# accident_year                                  461352.0
# location_easting_osgr                          461236.0
# location_northing_osgr                         461236.0
# longitude                                      461226.0
# latitude                                       461226.0
# police_force                                   461352.0
# accident_severity                              461352.0
# number_of_vehicles                             461352.0
# number_of_casualties                           461352.0
# day_of_week                                    461352.0
# local_authority_district                       461352.0
# first_road_class                               461352.0
# first_road_number                              461352.0
# road_type                                      461352.0
# speed_limit                                    461352.0
# junction_detail                                461352.0
# junction_control                               461352.0
# ...

# %%
## For good vision you can do a simple chart to show trend
df_desc.loc['count'].plot(marker='*')
plt.xticks(rotation=14)

## we will learn visualization later
# Out:
# (array([-5.,  0.,  5., 10., 15., 20., 25., 30.]),
#  [Text(-5.0, 0, 'special_conditions_at_site'),
#   Text(0.0, 0, 'accident_year'),
#   Text(5.0, 0, 'police_force'),
#   Text(10.0, 0, 'local_authority_district'),
#   Text(15.0, 0, 'junction_detail'),
#   Text(20.0, 0, 'pedestrian_crossing_physical_facilities'),
#   Text(25.0, 0, 'carriageway_hazards'),
#   Text(30.0, 0, '')])

# %%
df_cas.describe()
# Out:
#        casualty_index  accident_year  vehicle_reference  casualty_reference  \
# count   600332.000000  600332.000000      600332.000000       600332.000000
# mean    300165.500000    2018.355358           1.473603            1.386776
# std     173301.065238       1.088030           1.923189            2.734247
# min          0.000000    2017.000000           1.000000            1.000000
# 25%     150082.750000    2017.000000           1.000000            1.000000
# 50%     300165.500000    2018.000000           1.000000            1.000000
# 75%     450248.250000    2019.000000           2.000000            1.000000
# max     600331.000000    2020.000000         999.000000          992.000000
#
#        casualty_class  sex_of_casualty  age_of_casualty  age_band_of_casualty  \
# count   600332.000000    600332.000000    600332.000000         600332.000000
# mean         1.485818         1.392463        36.759541              6.316057
# ...

# %%
## Let's do for casuality
df_desc2 = df_cas.describe()
df_desc2.loc['count']
# Out:
# casualty_index                        600332.0
# accident_year                         600332.0
# vehicle_reference                     600332.0
# casualty_reference                    600332.0
# casualty_class                        600332.0
# sex_of_casualty                       600332.0
# age_of_casualty                       600332.0
# age_band_of_casualty                  600332.0
# casualty_severity                     600332.0
# pedestrian_location                   600332.0
# pedestrian_movement                   600332.0
# car_passenger                         600332.0
# bus_or_coach_passenger                600332.0
# pedestrian_road_maintenance_worker    600332.0
# casualty_type                         600332.0
# casualty_home_area_type               600332.0
# casualty_imd_decile                   600332.0
# Name: count, dtype: float64

# %% [markdown]
# **We can see that there are missing values in some columns of df_acc**

# %%
df_acc
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
## Actually, we can know those missing values using other different methods
df_acc.isnull()

# or isna()

# The nan will return True. But we cannot see all right?
# Out:
#         accident_index  accident_year  accident_reference  \
# 0                False          False               False
# 1                False          False               False
# 2                False          False               False
# 3                False          False               False
# 4                False          False               False
# ...                ...            ...                 ...
# 461347           False          False               False
# 461348           False          False               False
# 461349           False          False               False
# 461350           False          False               False
# 461351           False          False               False
#
#         location_easting_osgr  location_northing_osgr  longitude  latitude  \
# 0                       False                   False      False     False
# 1                       False                   False      False     False
# ...

# %%
df_acc.isnull().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          116
# location_northing_osgr                         116
# longitude                                      126
# latitude                                       126
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# ...

# %% [markdown]
# ### What do you do with the Missing Data ???
#
# - Remove them
# - Fill them
#
# __This is subjective!__

# %% [markdown]
# **A. Removing them**

# %%
## data.dropna()

# %% [markdown]
# ![dropna](drop.png "Drop").

# %%
## data.dropna() = drops any rows containing missing values
df_acc.dropna()
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
## data.dropna(how='all') = only drops rows containing that has all its columns to be NAs
df_acc.dropna(how='all')
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
## data.dropna(how='all' , axis=1) = only drops columns containing that has all its rows to be NAs
df_acc.dropna(how='all', axis=1)
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %% [markdown]
# **B. Filling them**

# %% [markdown]
# - data.fillna(what you want to fill the na with)
# - You can fill with certain value, the mean, or the output of certain functions

# %%
df_acc.fillna(0)
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
## You can fill with the mean of the column
df_acc.fillna(np.mean)
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#        location_easting_osgr location_northing_osgr longitude   latitude  \
# 0                   532920.0               196330.0 -0.080107  51.650061
# 1                   526790.0               181970.0 -0.173845  51.522425
# ...

# %%
## You can specify what you want to fill each column with using dictionary
df_acc.fillna({'location_easting_osgr':40, 'location_northing_osgr':80, 'longitude': 79, 'latitude':80})
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017           10001708
# 1       2017010009342           2017           10009342
# 2       2017010009344           2017           10009344
# 3       2017010009348           2017           10009348
# 4       2017010009350           2017           10009350
# ...               ...            ...                ...
# 461347  2020991027064           2020          991027064
# 461348  2020991029573           2020          991029573
# 461349  2020991030297           2020          991030297
# 461350  2020991030900           2020          991030900
# 461351  2020991032575           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %% [markdown]
# `I hope you know none of all we have been doing has not been perfected`

# %%
df_acc.isnull().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          116
# location_northing_osgr                         116
# longitude                                      126
# latitude                                       126
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# ...

# %% [markdown]
# ### So what should we do ?
# **It is still subjective. What is most important is backing your action with tangible reasons**
#  - We can go back to the guidance to understand the weight of these columns
#  - We can take more closer look

# %%
## Checking specifically for missing tables
df_acc[df_acc['location_easting_osgr'].isnull()]
# Out:
#        accident_index  accident_year accident_reference  \
# 28222   201704ED17168           2017          04ED17168
# 28865   201704EF17292           2017          04EF17292
# 30154   201704SC17240           2017          04SC17240
# 30411   201704WA17179           2017          04WA17179
# 39550   2017077353971           2017          077353971
# ...               ...            ...                ...
# 456858  202063A035620           2020          63A035620
# 456938  202063A059120           2020          63A059120
# 457171  202063C020320           2020          63C020320
# 457183  202063C024520           2020          63C024520
# 457449  202063D061520           2020          63D061520
#
#         location_easting_osgr  location_northing_osgr  longitude  latitude  \
# 28222                     NaN                     NaN        NaN       NaN
# 28865                     NaN                     NaN        NaN       NaN
# ...

# %% [markdown]
# **I think I should drop them**

# %%
## We have to put out inplace
df_acc.dropna(inplace=True)

# %%
# Now we are good to go
df_acc.isnull().sum()
# Out:
# accident_index                                 0
# accident_year                                  0
# accident_reference                             0
# location_easting_osgr                          0
# location_northing_osgr                         0
# longitude                                      0
# latitude                                       0
# police_force                                   0
# accident_severity                              0
# number_of_vehicles                             0
# number_of_casualties                           0
# date                                           0
# day_of_week                                    0
# time                                           0
# local_authority_district                       0
# local_authority_ons_district                   0
# local_authority_highway                        0
# first_road_class                               0
# first_road_number                              0
# ...

# %%
df_acc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461226 entries, 0 to 461351
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               461226 non-null  object
#  1   accident_year                                461226 non-null  int64
#  2   accident_reference                           461226 non-null  object
#  3   location_easting_osgr                        461226 non-null  float64
#  4   location_northing_osgr                       461226 non-null  float64
#  5   longitude                                    461226 non-null  float64
#  6   latitude                                     461226 non-null  float64
#  7   police_force                                 461226 non-null  int64
#  8   accident_severity                            461226 non-null  int64
# ...

# %% [markdown]
# ### You can now try to fix data type issues
# ` There are times you have to convert the data type `

# %%
df_acc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 461226 entries, 0 to 461351
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               461226 non-null  object
#  1   accident_year                                461226 non-null  int64
#  2   accident_reference                           461226 non-null  object
#  3   location_easting_osgr                        461226 non-null  float64
#  4   location_northing_osgr                       461226 non-null  float64
#  5   longitude                                    461226 non-null  float64
#  6   latitude                                     461226 non-null  float64
#  7   police_force                                 461226 non-null  int64
#  8   accident_severity                            461226 non-null  int64
# ...

# %%
df_cas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600332 entries, 0 to 600331
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   casualty_index                      600332 non-null  int64
#  1   accident_index                      600332 non-null  object
#  2   accident_year                       600332 non-null  int64
#  3   accident_reference                  600332 non-null  object
#  4   vehicle_reference                   600332 non-null  int64
#  5   casualty_reference                  600332 non-null  int64
#  6   casualty_class                      600332 non-null  int64
#  7   sex_of_casualty                     600332 non-null  int64
#  8   age_of_casualty                     600332 non-null  int64
#  9   age_band_of_casualty                600332 non-null  int64
#  10  casualty_severity                   600332 non-null  int64
# ...

# %% [markdown]
# ### Outliers Detection
# - There are several ways to go about outliers detection.
# - At this junction you may have to deploy some visualization skills
# - We can be very petty and rigorous.
# - We are going to investigate two parameters in this class

# %%
df_acc.head()
# Out:
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  2017010001708           2017           10001708               532920.0
# 1  2017010009342           2017           10009342               526790.0
# 2  2017010009344           2017           10009344               535200.0
# 3  2017010009348           2017           10009348               534340.0
# 4  2017010009350           2017           10009350               533680.0
#
#    location_northing_osgr  longitude   latitude  police_force  \
# 0                196330.0  -0.080107  51.650061             1
# 1                181970.0  -0.173845  51.522425             1
# 2                181260.0  -0.052969  51.514096             1
# 3                193560.0  -0.060658  51.624832             1
# 4                187820.0  -0.072372  51.573408             1
#
#    accident_severity  number_of_vehicles  ...  \
# 0                  1                   2  ...
# 1                  3                   2  ...
# ...

# %% [markdown]
# `Let's investigate our lsoa_of_accident_location`

# %%
## I pick it
df_acc['lsoa_of_accident_location']
# Out:
# 0         E01001450
# 1         E01004702
# 2         E01004298
# 3         E01001429
# 4         E01001808
#             ...
# 461347           -1
# 461348           -1
# 461349           -1
# 461350           -1
# 461351           -1
# Name: lsoa_of_accident_location, Length: 461226, dtype: object

# %%
## I can get the unique values and count them
df_acc['lsoa_of_accident_location'].unique()
# Out:
# array(['E01001450', 'E01004702', 'E01004298', ..., 'W01001793',
#        'W01000636', -1], dtype=object)

# %%
## count them
len(df_acc['lsoa_of_accident_location'].unique())
# Out:
# 33749

# %%
df_acc['lsoa_of_accident_location'].value_counts()
# Out:
# -1           20425
# -1            2600
# E01032739      629
# E01004736      474
# E01033595      324
#              ...
# E01020798        1
# E01020623        1
# E01020666        1
# E01020846        1
# E01006710        1
# Name: lsoa_of_accident_location, Length: 33749, dtype: int64

# %%
df_acc['lsoa_of_accident_location'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 461226 entries, 0 to 461351
# Series name: lsoa_of_accident_location
# Non-Null Count   Dtype
# --------------   -----
# 461226 non-null  object
# dtypes: object(1)
# memory usage: 7.0+ MB

# %% [markdown]
# ### What is LSOA again ?
# [check here](https://www.ons.gov.uk/methodology/geography/geographicalproducts/namescodesandlookups/namesandcodeslistings/namesandcodesforsuperoutputareassoa)
#
# **-1 seems strange**

# %%
# There a lot of them. Getting rid might be colossal or should I?

# %%
## Let's replace this time

# %% [markdown]
# **How to replace an element through a column**

# %%
df_acc['lsoa_of_accident_location'].replace(-1, 0, inplace=True)

# %%
df_acc['lsoa_of_accident_location'].value_counts()
# Out:
# -1           20425
# 0             2600
# E01032739      629
# E01004736      474
# E01033595      324
#              ...
# E01020798        1
# E01020623        1
# E01020666        1
# E01020846        1
# E01006710        1
# Name: lsoa_of_accident_location, Length: 33749, dtype: int64

# %%
#### It can be stubborn

# %% [markdown]
# **Learn how to fetch out you intent from you total set using conditions**

# %%
df_acc[df_acc['lsoa_of_accident_location'] == '-1']
# Out:
#          accident_index  accident_year accident_reference  \
# 44302       2.01712E+12           2017          120117754
# 110041  2017500000000.0           2017          500205948
# 122869    201791NE00034           2017          91NE00034
# 122870    201791NE01209           2017          91NE01209
# 122871    201791NE01342           2017          91NE01342
# ...                 ...            ...                ...
# 458747      2.02099E+12           2020          990950560
# 458748      2.02099E+12           2020          990950561
# 458749      2.02099E+12           2020          990950566
# 458750      2.02099E+12           2020          990950567
# 458751      2.02099E+12           2020          990950595
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 44302                446173.0                431086.0  -1.300889  53.774089
# 110041               243528.0                 58797.0  -4.203438  50.408142
# ...

# %%
df_acc['lsoa_of_accident_location'].replace('-1', 0, inplace=True)

# %%
df_acc['lsoa_of_accident_location'].value_counts()
## All good now
# Out:
# 0            23025
# E01032739      629
# E01004736      474
# E01033595      324
# E01002444      274
#              ...
# E01013053        1
# E01003457        1
# E01012797        1
# W01000356        1
# W01000636        1
# Name: lsoa_of_accident_location, Length: 33748, dtype: int64

# %% [markdown]
# ### Age

# %%
df_cas
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 0                    0  2017010001708           2017          010001708
# 1                    1  2017010001708           2017          010001708
# 2                    2  2017010001708           2017          010001708
# 3                    3  2017010009342           2017          010009342
# 4                    4  2017010009344           2017          010009344
# ...                ...            ...            ...                ...
# 600327          600327  2020991027064           2020          991027064
# 600328          600328  2020991029573           2020          991029573
# 600329          600329  2020991030297           2020          991030297
# 600330          600330  2020991030900           2020          991030900
# 600331          600331  2020991032575           2020          991032575
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %%
df_cas['age_of_casualty']
# Out:
# 0         18
# 1         19
# 2         18
# 3         33
# 4         31
#           ..
# 600327    11
# 600328    63
# 600329    38
# 600330    76
# 600331    48
# Name: age_of_casualty, Length: 600332, dtype: int64

# %%
sns.scatterplot(data=df_cas['age_of_casualty'], s=2)
# You can find some values around zero....
# Out:
# <AxesSubplot:ylabel='age_of_casualty'>

# %% [markdown]
# **Can someone be zero years old ?**

# %%
df_cas[df_cas['age_of_casualty']<=0]
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 478                478  2017010010325           2017          010010325
# 519                519  2017010010420           2017          010010420
# 685                685  2017010010910           2017          010010910
# 870                870  2017010011502           2017          010011502
# 935                935  2017010011685           2017          010011685
# ...                ...            ...            ...                ...
# 597578          597578  2020990962144           2020          990962144
# 597929          597929  2020990968821           2020          990968821
# 598150          598150  2020990972231           2020          990972231
# 598581          598581  2020990978466           2020          990978466
# 598843          598843  2020990983789           2020          990983789
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %%
df_cas[df_cas['age_of_casualty']<=0]['age_of_casualty'].unique()
# Out:
# array([ 0, -1], dtype=int64)

# %% [markdown]
# **How would you interpret this abnormality?**

# %%
## You might choose to drop the -1 and then assume the 0 are children less than a year

# %% [markdown]
# `Let's drop the those whose age are -1`

# %%
df_cas[df_cas['age_of_casualty']==-1]
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 685                685  2017010010910           2017          010010910
# 1233              1233  2017010012468           2017          010012468
# 1305              1305  2017010012640           2017          010012640
# 1310              1310  2017010012662           2017          010012662
# 1353              1353  2017010012819           2017          010012819
# ...                ...            ...            ...                ...
# 594845          594845  202063C000521           2020          63C000521
# 594996          594996  202063C071820           2020          63C071820
# 595177          595177  202063D041920           2020          63D041920
# 595210          595210  202063D052820           2020          63D052820
# 595286          595286  202063D073620           2020          63D073620
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %% [markdown]
# **How do you drop them? Do you remember the two ways we can use dropna()**

# %% [markdown]
#  we can use drop() and axis=0...but we need the index to use axis=1

# %%
err_age = df_cas[df_cas['age_of_casualty']==-1].index
err_age
# Out:
# Int64Index([   685,   1233,   1305,   1310,   1353,   1434,   1511,   1762,
#               1854,   2045,
#             ...
#             593123, 593124, 593129, 593326, 594610, 594845, 594996, 595177,
#             595210, 595286],
#            dtype='int64', length=10838)

# %%
df_cas.drop(err_age, axis=0)
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 0                    0  2017010001708           2017          010001708
# 1                    1  2017010001708           2017          010001708
# 2                    2  2017010001708           2017          010001708
# 3                    3  2017010009342           2017          010009342
# 4                    4  2017010009344           2017          010009344
# ...                ...            ...            ...                ...
# 600327          600327  2020991027064           2020          991027064
# 600328          600328  2020991029573           2020          991029573
# 600329          600329  2020991030297           2020          991030297
# 600330          600330  2020991030900           2020          991030900
# 600331          600331  2020991032575           2020          991032575
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %%
df_cas.drop(err_age, axis=0, inplace=True)

# %%
df_cas
# Out:
#         casualty_index accident_index  accident_year accident_reference  \
# 0                    0  2017010001708           2017          010001708
# 1                    1  2017010001708           2017          010001708
# 2                    2  2017010001708           2017          010001708
# 3                    3  2017010009342           2017          010009342
# 4                    4  2017010009344           2017          010009344
# ...                ...            ...            ...                ...
# 600327          600327  2020991027064           2020          991027064
# 600328          600328  2020991029573           2020          991029573
# 600329          600329  2020991030297           2020          991030297
# 600330          600330  2020991030900           2020          991030900
# 600331          600331  2020991032575           2020          991032575
#
#         vehicle_reference  casualty_reference  casualty_class  \
# ...

# %%
df_cas.set_index('casualty_index', inplace=True)

# %%
df_cas
# Out:
#                accident_index  accident_year accident_reference  \
# casualty_index
# 0               2017010001708           2017          010001708
# 1               2017010001708           2017          010001708
# 2               2017010001708           2017          010001708
# 3               2017010009342           2017          010009342
# 4               2017010009344           2017          010009344
# ...                       ...            ...                ...
# 600327          2020991027064           2020          991027064
# 600328          2020991029573           2020          991029573
# 600329          2020991030297           2020          991030297
# 600330          2020991030900           2020          991030900
# 600331          2020991032575           2020          991032575
#
#                 vehicle_reference  casualty_reference  casualty_class  \
# casualty_index
# 0                               1                   1               2
# ...

# %% [markdown]
# **A less than one year baby cannot be travelling alone, let's find if there is anyone travelling with them**
# - `we use accident reference to know if they are wrongly slotted into the data`

# %%
zero_age = df_cas[df_cas['age_of_casualty']==0]
zero_age
# Out:
#                accident_index  accident_year accident_reference  \
# casualty_index
# 478             2017010010325           2017          010010325
# 519             2017010010420           2017          010010420
# 870             2017010011502           2017          010011502
# 935             2017010011685           2017          010011685
# 936             2017010011685           2017          010011685
# ...                       ...            ...                ...
# 597578          2020990962144           2020          990962144
# 597929          2020990968821           2020          990968821
# 598150          2020990972231           2020          990972231
# 598581          2020990978466           2020          990978466
# 598843          2020990983789           2020          990983789
#
#                 vehicle_reference  casualty_reference  casualty_class  \
# casualty_index
# 478                             1                   2               2
# ...

# %% [markdown]
# #### What do we do ?
# We can do a valuecounts on those who had accident with the same reference index and capture what we want

# %%
zero_age['accident_reference'].value_counts()
# Out:
# 051840170    6
# 010108114    4
# 1378U1156    3
# 010011685    3
# 010117588    2
#             ..
# 010122360    1
# 010122982    1
# 010123137    1
# 010123463    1
# 990983789    1
# Name: accident_reference, Length: 950, dtype: int64

# %% [markdown]
# `Let's use this opportunity to learn a function called apply.`
# - **Very Resourceful!**

# %% [markdown]
# Apply is used to apply a function along an axis of the DataFrame
# - Let's use it to capture those that truly less than a year

# %% [markdown]
# ### By the way...A brief explanation of how apply works

# %%
dd = pd.DataFrame({'a':[12,3232,89], 'b' : ['go', 'please','now']})
dd
# Out:
#       a       b
# 0    12      go
# 1  3232  please
# 2    89     now

# %%
def tester(x):
    if x > 50:
        return 10
    else:
        return x

# %%
dd['c'] = dd['a'].apply(tester)

# %%
dd
# Out:
#       a       b   c
# 0    12      go  12
# 1  3232  please  10
# 2    89     now  10

# %% [markdown]
# ### Analysis resumes

# %%
def wrong_young_catcher(x):
    population = len(df_cas[df_cas['accident_reference'] == x])
    if population == 1:
        return population

# %%
failed = zero_age['accident_reference'].apply(wrong_young_catcher)

# %%
failed
# Out:
# casualty_index
# 478       NaN
# 519       NaN
# 870       1.0
# 935       NaN
# 936       NaN
#          ...
# 597578    NaN
# 597929    NaN
# 598150    NaN
# 598581    NaN
# 598843    NaN
# Name: accident_reference, Length: 977, dtype: float64

# %%
failed.dropna(inplace=True)

# %%
failed.index
# Out:
# Int64Index([   870,   3158,   3715,   5910,   6481,   7378,   7661,   7764,
#               8103,   8533,
#             ...
#             544705, 547446, 561602, 571060, 574405, 582243, 591428, 592311,
#             593966, 594799],
#            dtype='int64', name='casualty_index', length=357)

# %%
### Now drop those samples from the casaulity dataframe
df_cas.drop(failed.index, axis=0, inplace=True)

# %%
df_cas
# Out:
#                accident_index  accident_year accident_reference  \
# casualty_index
# 0               2017010001708           2017          010001708
# 1               2017010001708           2017          010001708
# 2               2017010001708           2017          010001708
# 3               2017010009342           2017          010009342
# 4               2017010009344           2017          010009344
# ...                       ...            ...                ...
# 600327          2020991027064           2020          991027064
# 600328          2020991029573           2020          991029573
# 600329          2020991030297           2020          991030297
# 600330          2020991030900           2020          991030900
# 600331          2020991032575           2020          991032575
#
#                 vehicle_reference  casualty_reference  casualty_class  \
# casualty_index
# 0                               1                   1               2
# ...

# %% [markdown]
# ### Data Transformation

# %%
df_acc
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017           10001708
# 1       2017010009342           2017           10009342
# 2       2017010009344           2017           10009344
# 3       2017010009348           2017           10009348
# 4       2017010009350           2017           10009350
# ...               ...            ...                ...
# 461347  2020991027064           2020          991027064
# 461348  2020991029573           2020          991029573
# 461349  2020991030297           2020          991030297
# 461350  2020991030900           2020          991030900
# 461351  2020991032575           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
df_cas
# Out:
#                accident_index  accident_year accident_reference  \
# casualty_index
# 0               2017010001708           2017          010001708
# 1               2017010001708           2017          010001708
# 2               2017010001708           2017          010001708
# 3               2017010009342           2017          010009342
# 4               2017010009344           2017          010009344
# ...                       ...            ...                ...
# 600327          2020991027064           2020          991027064
# 600328          2020991029573           2020          991029573
# 600329          2020991030297           2020          991030297
# 600330          2020991030900           2020          991030900
# 600331          2020991032575           2020          991032575
#
#                 vehicle_reference  casualty_reference  casualty_class  \
# casualty_index
# 0                               1                   1               2
# ...

# %% [markdown]
# **We can actually merge the two dataframe together since there is a key..Look up on accident index**

# %% [markdown]
# `How to Merge`
# - pandas.merge(df1, df2, on='key')
# - pandas.concat()

# %% [markdown]
# ![Merge](merge.png "Merge Function").

# %%
df_acc_cas = pd.merge(df_acc, df_cas, on='accident_index')
df_acc_cas

# we now have 53 columns
# Out:
#       accident_index  accident_year_x accident_reference_x  \
# 0      201701T158779             2017            01T158779
# 1      201701T163737             2017            01T163737
# 2      201701T171585             2017            01T171585
# 3      201701T171585             2017            01T171585
# 4      201701T172074             2017            01T172074
# ...              ...              ...                  ...
# 86303  202063DF01620             2020            63DF01620
# 86304  202063DF01620             2020            63DF01620
# 86305  202063DF01620             2020            63DF01620
# 86306  202063DF01620             2020            63DF01620
# 86307  202063DF01620             2020            63DF01620
#
#        location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                   532783.0                180419.0  -0.088097  51.507111
# 1                   531382.0                181569.0  -0.107844  51.517773
# ...

# %%
df_analysis = df_acc_cas.copy()

# %%
df_analysis
# Out:
#       accident_index  accident_year_x accident_reference_x  \
# 0      201701T158779             2017            01T158779
# 1      201701T163737             2017            01T163737
# 2      201701T171585             2017            01T171585
# 3      201701T171585             2017            01T171585
# 4      201701T172074             2017            01T172074
# ...              ...              ...                  ...
# 86303  202063DF01620             2020            63DF01620
# 86304  202063DF01620             2020            63DF01620
# 86305  202063DF01620             2020            63DF01620
# 86306  202063DF01620             2020            63DF01620
# 86307  202063DF01620             2020            63DF01620
#
#        location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                   532783.0                180419.0  -0.088097  51.507111
# 1                   531382.0                181569.0  -0.107844  51.517773
# ...

# %% [markdown]
# **Tranforming Data using Function**

# %% [markdown]
# #### Let's tranform the sex of the data based on the given standard
# 1. Male
# 2. Female
# 3. Not known

# %%
def age_converter(age):
    if age == 1:
        return 'Male'
    elif age == 2:
        return 'Female'
    elif age == 3:
        return 'Not Known'

# %%
df_acc_cas['sex_of_casualty'] = df_acc_cas['sex_of_casualty'].apply(age_converter)

# %%
df_acc_cas
# Out:
#       accident_index  accident_year_x accident_reference_x  \
# 0      201701T158779             2017            01T158779
# 1      201701T163737             2017            01T163737
# 2      201701T171585             2017            01T171585
# 3      201701T171585             2017            01T171585
# 4      201701T172074             2017            01T172074
# ...              ...              ...                  ...
# 86303  202063DF01620             2020            63DF01620
# 86304  202063DF01620             2020            63DF01620
# 86305  202063DF01620             2020            63DF01620
# 86306  202063DF01620             2020            63DF01620
# 86307  202063DF01620             2020            63DF01620
#
#        location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                   532783.0                180419.0  -0.088097  51.507111
# 1                   531382.0                181569.0  -0.107844  51.517773
# ...

# %%
df_acc_cas['sex_of_casualty'].value_counts().plot(kind='barh')
# You can from here begin to draw several inferences
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Data Aggregation**

# %% [markdown]
# `dataframe.groupby()`

# %%
df_acc
# Out:
#          accident_index  accident_year accident_reference  \
# 0       2017010000000.0           2017           10001708
# 1       2017010000000.0           2017           10009342
# 2       2017010000000.0           2017           10009344
# 3       2017010000000.0           2017           10009348
# 4       2017010000000.0           2017           10009350
# ...                 ...            ...                ...
# 461347  2020990000000.0           2020          991027064
# 461348  2020990000000.0           2020          991029573
# 461349  2020990000000.0           2020          991030297
# 461350  2020990000000.0           2020          991030900
# 461351  2020990000000.0           2020          991032575
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
## Let's Groupby Year
df_acc_cas.groupby('accident_year_x').count()
# Out:
#                  accident_index  accident_reference_x  location_easting_osgr  \
# accident_year_x
# 2017                     121950                121950                 121950
# 2018                     138623                138623                 138623
# 2019                     120305                120305                 120305
# 2020                      88772                 88772                  88772
#
#                  location_northing_osgr  longitude  latitude  police_force  \
# accident_year_x
# 2017                             121950     121950    121950        121950
# 2018                             138623     138623    138623        138623
# 2019                             120305     120305    120305        120305
# 2020                              88772      88772     88772         88772
#
#                  accident_severity  number_of_vehicles  number_of_casualties  \
# accident_year_x
# ...

# %%
df_acc_cas.groupby(['accident_year_x','sex_of_casualty']).size()
# Out:
# accident_year_x  sex_of_casualty
# 2017             Female             50120
#                  Male               71827
# 2018             Female             57165
#                  Male               81443
# 2019             Female             48912
#                  Male               71337
# 2020             Female             32556
#                  Male               55995
# dtype: int64

# %%
df_acc_cas.groupby(['accident_year_x','sex_of_casualty']).mean()
# Out:
#                                  location_easting_osgr  \
# accident_year_x sex_of_casualty
# 2017            Female                   427491.831844
#                 Male                     431259.151754
# 2018            Female                   435974.739491
#                 Male                     439106.813256
# 2019            Female                   429547.355904
#                 Male                     433137.591026
# 2020            Female                   438643.840183
#                 Male                     446348.818930
#
#                                  location_northing_osgr  longitude   latitude  \
# accident_year_x sex_of_casualty
# 2017            Female                    332970.663368  -1.615891  52.886761
#                 Male                      326942.170744  -1.560035  52.832633
# 2018            Female                    303062.832677  -1.487378  52.615294
#                 Male                      298381.205997  -1.442617  52.573310
# ...

# %%
## You can iterate through your group and carry out further analysis
for (k1, k2), group in df_acc_cas.groupby(['accident_year_x','sex_of_casualty']):
    print(k1,k2)
    print(group)
# Out:
# 2017 Female
#        accident_index  accident_year_x accident_reference_x  \
# 0       2017010054366             2017            010054366
# 1       2017010054367             2017            010054367
# 2       2017010054367             2017            010054367
# 4       2017010054370             2017            010054370
# 6       2017010054371             2017            010054371
# ...               ...              ...                  ...
# 121935  2017984118817             2017            984118817
# 121936  2017984118917             2017            984118917
# 121940  2017984119917             2017            984119917
# 121942  2017984120717             2017            984120717
# 121945  2017984121217             2017            984121217
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    517360.0                169480.0  -0.313847  51.412204
# 1                    516390.0                180360.0  -0.324210  51.510191
# ...

# %% [markdown]
# ### Assignment
# - Read, practice, and explore on pandas.concat(). Provide an example from your understanding
# - Do the following using the horror dataset explored in class 08
#     1. Carry out data cleaning on the dataset
#     2. Select any 2 column of the columns of the dataset and carry out exhaustive data cleaning on them
